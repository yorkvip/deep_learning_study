# %%
import torch
import torch.nn.functional as F
from torch import nn

class CenteredLayer(nn.Module):
    def __init__(self):
        super().__init__()
        
    def forward(self, X):
         return X - X.mean()
layer=CenteredLayer()
layer(torch.FloatTensor([1,2,3,4,5]))
# Out:
# tensor([-2., -1.,  0.,  1.,  2.])

# %%
net=nn.Sequential(nn.Linear(5,1),CenteredLayer())

Y=net(torch.FloatTensor([[1,2,3,4,5]]))
Y.mean()
# Out:
# tensor(0., grad_fn=<MeanBackward0>)

# %%
class MyLinear(nn.Module):
    def __init__(self,in_uints,units):
        super().__init__()
        self.weight=nn.Parameter(torch.randn(in_uints,units))
        self.bias=nn.Parameter(torch.randn(units,))
    def forward(self,X):
        linear=torch.matmul(X,self.weight.data)+self.bias.data
        return F.relu(linear)
dense=MyLinear(5,3)
dense.weight
# Out:
# Parameter containing:
# tensor([[-1.1175, -1.2053, -0.3985],
#         [ 1.5428, -1.3322, -0.5935],
#         [-0.8891, -1.0415,  0.1776],
#         [-0.5619, -0.5735,  0.6485],
#         [-0.2735,  0.5515, -0.5804]], requires_grad=True)

# %% [markdown]
# 可以执行正向计算 or 构建模型
