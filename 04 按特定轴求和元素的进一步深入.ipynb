# %%
import torch
a=torch.ones((2,5,4))
print(a.shape)
# Out:
# torch.Size([2, 5, 4])

# %%
print(a.sum(axis=1))
# Out:
# tensor([[5., 5., 5., 5.],
#         [5., 5., 5., 5.]])

# %%
print(a.sum(axis=0))
# Out:
# tensor([[2., 2., 2., 2.],
#         [2., 2., 2., 2.],
#         [2., 2., 2., 2.],
#         [2., 2., 2., 2.],
#         [2., 2., 2., 2.]])
